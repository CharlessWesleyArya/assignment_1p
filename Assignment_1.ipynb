# %% [markdown]
# Assignment 1:
# ------------------
#
# 1.)* is an MULTIPLICATION OPERATOR
#
#    'hello' is a STRING VALUE.
#
#    -87.8 is a FLOATING POINT VALUE.
#
#    - is a SUBTRACTION OPERATOR.
#
#    / is a DIVISION OPERATOR.
#
#    + is a ADDITION OPERATOR.
#
#    6 is a INTEGER VALUE.
#
#
# 2.)
#
# String: String is a value in which we can give one or more characters at a time .
#
# Variable: Variable is used to store values of any types. it is refernce to a value which is stored in some memory.
#
#
# 3.) 3 different data types are
#
#     int) int is a data type is used to  store integer type values whether it is positive or negative.
#     ex: 2,45,134567.
#
#     float) float is a data type is used to store Floating type values.
#     ex: 12.6, 99.4.
#
#     Complex Numbers) this type is used to store complex values.
#     ex: 4+7j.
#
#
# 4.) Expression is made up of combination of variables ,operators and values.
#     Expression do a particular operations and gives some result at the end.
#
#     ex: x=1+3;
#         here we are giving an assignment and addition operators, adding of 1+3 ,and the result will be stored in x, so after the complition of this statement some result is given by the expression .
#
#
# 5.) Expression is made up of combination of variables ,operators and values where as statement will just an instruction given.
#
# in this spam =10 will assign the value of 10 into spam variable and will not do any operation
#
#
#
# 6.) bacon still remains as 22 because after initialization we are just adding 1 and is going to show the reslut , but the addition is not storing in any variable even in bacon .so bacon contains 22.
#
#
# 7.) the values of the given two statements will be same. way of operation is different but the reslut will remain same  because the number of multiplication and addition are same.
#
# 'spam'+'spamspam' ='spamspamspam'
#
# 'spam'*3= 'spamspamspam'.
#
#
# 8.)In python we can give alpha-numberic character and underscores as a variable name.
#
# but we cannot start a variable name with numbers ,this is the reason for 100 cant be a valid variable.
#
#
# 9.)There are three Pre-defined functions by which we can change one value to our required type like integer,floating and string , they are
#
# int() --> is used to change another data type value to integer value.
#
# float()--> is used to change another data type values to floating value.
#
# str()--> is used to change another data type values to string type values.
#
#
# 10.) 'I have eaten' +99+'burritos.'
#
#  this expression will result error ,becaues we cannot concatinate string and integer values , we can only concate string with a strig, and we can add some numerical values to int not string values so this is getting error.
#
#  we can fix this by removing 99 which is integer and can give a string in that place '99' or 'ninety nine' .
